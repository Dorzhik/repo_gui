# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

c = np.linspace (0, 2 * np.pi, 100)
plt.figure(figsize = (5,5))
plt.plot (np.cos(c), np.sin(c))
plt.show()

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

c = np.linspace (0, 2 * np.pi, 100)
u = 1
v = 0.5
a = 4
b = 2

plt.plot ( u + a * np.cos(c), v + b * np.sin(c))
plt.show()

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import decimal

xmin = -30
xmax = 30
dx = 0.1

xlist = np.around(np.arange(xmin, xmax, dx), decimals = 6)
ylist = 1 / xlist

plt.plot(xlist, ylist)
plt.show()
# Out:
# <ipython-input-6-41539cd67a06>:12: RuntimeWarning: divide by zero encountered in true_divide
#   ylist = 1 / xlist

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

f = lambda x, y: x + y
fig = plt.figure(figsize = (10, 10))
ax = fig.add_subplot(1,1,1, projection = '3d')
xval = np.linspace(-5, 5, 100)
yval = np.linspace(-5, 5, 100)
x, y = np.meshgrid(xval, yval)
z = f(x,y)
z1 = f(x,y) + 2
surf = ax.plot_surface(x, y, z, rstride = 10, cstride = 10)
surf = ax.plot_surface(x, y, z1, rstride = 10, cstride = 10)

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize = (10, 10))
ax = fig.add_subplot(1,1,1, projection = '3d')

u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)

x = 5 * np.outer(np.cos(u), np.sin(v))
y = 5 * np.outer(np.sin(u), np.sin(v))
z = 5 * np.outer(np.ones(np.size(u)), np.cos(v))

ax.plot_surface(x, y, z, rstride = 5, cstride = 5)
plt.show()
#сфера

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize = (10, 10))
ax = fig.add_subplot(1,1,1, projection = '3d')

xval = np.linspace(-1, 1, 100)
yval = np.linspace(-1, 1, 100)

x, y = np.meshgrid(xval, yval)
z = np.pi * y**2

surf = ax.plot_surface(x, y, z, rstride = 10, cstride = 10)
#цилиндр
